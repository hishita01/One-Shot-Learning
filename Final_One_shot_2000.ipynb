# %%
import sys
import numpy as np
import pandas as pd
import imageio
from imageio import imread
import pickle
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2
import time

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model

# from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import concatenate
# from keras.layers.core import Lambda, Flatten, Dense
from tensorflow.keras.layers import (
    Conv2D, ZeroPadding2D, Activation, Input, concatenate,
    BatchNormalization, MaxPooling2D, Concatenate,
    Lambda, Flatten, Dense
)
from keras.initializers import glorot_uniform

from tensorflow.keras.layers import Layer, InputSpec
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import numpy.random as rng

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train_folder = "/content/drive/MyDrive/Honors_project/Dataset/images_background"
val_folder = '/content/drive/MyDrive/Honors_project/Dataset/images_evaluation'
save_path = '/content/drive/MyDrive/Honors_project/Dataset/Data_save'

# %%
def loadimgs(path,n = 0):
    '''
    path => Path of train directory or test directory
    '''
    X=[]
    y = []
    cat_dict = {}
    lang_dict = {}
    curr_y = n
    # we load every alphabet seperately so we can isolate them later
    for alphabet in os.listdir(path):
        print("loading alphabet: " + alphabet)
        lang_dict[alphabet] = [curr_y,None]
        alphabet_path = os.path.join(path,alphabet)
        # every letter/category has it's own column in the array, so  load seperately
        for letter in os.listdir(alphabet_path):
            cat_dict[curr_y] = (alphabet, letter)
            category_images=[]
            letter_path = os.path.join(alphabet_path, letter)
            # read all the images in the current category
            for filename in os.listdir(letter_path):
                image_path = os.path.join(letter_path, filename)
                image = imread(image_path)
                category_images.append(image)
                y.append(curr_y)
            try:
                X.append(np.stack(category_images))
            # edge case  - last one
            except ValueError as e:
                print(e)
                print("error - category_images:", category_images)
            curr_y += 1
            lang_dict[alphabet][1] = curr_y - 1
    y = np.vstack(y)
    X = np.stack(X)
    return X,y,lang_dict

# %%
X,y,c=loadimgs(train_folder)
# Out:
# loading alphabet: Tagalog
# <ipython-input-4-b88039de8434>:23: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(image_path)
# loading alphabet: Sanskrit
# loading alphabet: N_Ko
# loading alphabet: Korean
# loading alphabet: Mkhedruli_(Georgian)
# loading alphabet: Ojibwe_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Malay_(Jawi_-_Arabic)
# loading alphabet: Latin
# loading alphabet: Syriac_(Estrangelo)
# loading alphabet: Tifinagh
# loading alphabet: Cyrillic
# loading alphabet: Japanese_(katakana)
# loading alphabet: Greek
# loading alphabet: Futurama
# loading alphabet: Japanese_(hiragana)
# loading alphabet: Early_Aramaic
# loading alphabet: Gujarati
# loading alphabet: Hebrew
# loading alphabet: Inuktitut_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Grantha
# loading alphabet: Anglo-Saxon_Futhorc
# loading alphabet: Burmese_(Myanmar)
# loading alphabet: Balinese
# loading alphabet: Arcadian
# loading alphabet: Blackfoot_(Canadian_Aboriginal_Syllabics)
# loading alphabet: Asomtavruli_(Georgian)
# loading alphabet: Armenian
# loading alphabet: Alphabet_of_the_Magi
# loading alphabet: Bengali
# loading alphabet: Braille

# %%
#with open(os.path.join(save_path,"train.pickle"), "wb") as f:
#   pickle.dump((X,c),f)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-19-536312ca0c9e> in <cell line: 1>()
# ----> 1 with open(os.path.join(save_path,"train.pickle"), "wb") as f:
#       2     pickle.dump((X,c),f)
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/MyDrive/Honors_project/Dataset/Data_save/train.pickle'

# %%
f = open(save_path+"train.pickle","wb")
pickle.dump((X,c),f)
f.close()

# %%
Xval,yval,cval=loadimgs(val_folder)
# Out:
# loading alphabet: Tibetan
# <ipython-input-4-b88039de8434>:23: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(image_path)
# loading alphabet: Syriac_(Serto)
# loading alphabet: Sylheti
# loading alphabet: Tengwar
# loading alphabet: Mongolian
# loading alphabet: Oriya
# loading alphabet: Manipuri
# loading alphabet: ULOG
# loading alphabet: Malayalam
# loading alphabet: Old_Church_Slavonic_(Cyrillic)
# loading alphabet: Keble
# loading alphabet: Aurek-Besh
# loading alphabet: Atlantean
# loading alphabet: Kannada
# loading alphabet: Glagolitic
# loading alphabet: Angelic
# loading alphabet: Avesta
# loading alphabet: Gurmukhi
# loading alphabet: Ge_ez
# loading alphabet: Atemayar_Qelisayer

# %%
#with open(os.path.join(save_path,"val.pickle"), "wb") as f:
#   pickle.dump((Xval,cval),f)
f = open(save_path+"val.pickle","wb")
pickle.dump((Xval,cval),f)
f.close()

# %%
def initialize_weights(shape, dtype=None):
  # dtype not name
#     """
#         The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
#         suggests to initialize CNN layer weights with mean as 0.0 and standard deviation of 0.01
#     """
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

# %%
def initialize_bias(shape, dtype=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer bias with mean as 0.5 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
def get_siamese_model(input_shape):
    """
        Model architecture based on the one provided in: http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
    """

    # Define the tensors for the two input images
    left_input = Input(input_shape)
    right_input = Input(input_shape)

    # Convolutional Neural Network
    model = Sequential()
    model.add(Conv2D(64, (10,10), activation='relu', input_shape=input_shape,
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (7,7), activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(128, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling2D())
    model.add(Conv2D(256, (4,4), activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias))

    # Generate the encodings (feature vectors) for the two images
    encoded_l = model(left_input)
    encoded_r = model(right_input)

    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])

    # Add a dense layer with a sigmoid unit to generate the similarity score
    prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias)(L1_distance)

    # Connect the inputs with the outputs
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

    # return the model
    return siamese_net

# %%
model = get_siamese_model((105, 105, 1))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 105, 105, 1)]        0         []
#
#  input_2 (InputLayer)        [(None, 105, 105, 1)]        0         []
#
#  sequential (Sequential)     (None, 4096)                 3894764   ['input_1[0][0]',
#                                                           8          'input_2[0][0]']
#
#  lambda (Lambda)             (None, 4096)                 0         ['sequential[0][0]',
#                                                                      'sequential[1][0]']
#
#  dense_1 (Dense)             (None, 1)                    4097      ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 38951745 (148.59 MB)
# Trainable params: 38951745 (148.59 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# from IPython.display import Image
# Image(retina=True, filename='model.png')
import matplotlib.pyplot as plt
from IPython.display import Image
from tensorflow.keras.utils import plot_model

# Assuming 'model' is your Keras model
model = get_siamese_model((105, 105, 1))

# Generate the model summary plot
plot_path = 'model.png'
plot_model(model, to_file=plot_path, show_shapes=True, show_layer_names=True)

# Display the saved image
Image(retina=True, filename=plot_path)

# %%
optimizer = Adam(lr = 0.00006)
model.compile(loss="binary_crossentropy",optimizer=optimizer)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
with open(os.path.join(save_path, "train.pickle"), "rb") as f:
    (Xtrain, train_classes) = pickle.load(f)

print("Training alphabets: \n")
print(list(train_classes.keys()))
# Out:
# Training alphabets:
#
# ['Tagalog', 'Sanskrit', 'N_Ko', 'Korean', 'Mkhedruli_(Georgian)', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Malay_(Jawi_-_Arabic)', 'Latin', 'Syriac_(Estrangelo)', 'Tifinagh', 'Cyrillic', 'Japanese_(katakana)', 'Greek', 'Futurama', 'Japanese_(hiragana)', 'Early_Aramaic', 'Gujarati', 'Hebrew', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Grantha', 'Anglo-Saxon_Futhorc', 'Burmese_(Myanmar)', 'Balinese', 'Arcadian', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Asomtavruli_(Georgian)', 'Armenian', 'Alphabet_of_the_Magi', 'Bengali', 'Braille']

# %%
with open(os.path.join(save_path, "val.pickle"), "rb") as f:
    (Xval, val_classes) = pickle.load(f)

print("Validation alphabets:", end="\n\n")
print(list(val_classes.keys()))
# Out:
# Validation alphabets:
#
# ['Tibetan', 'Syriac_(Serto)', 'Sylheti', 'Tengwar', 'Mongolian', 'Oriya', 'Manipuri', 'ULOG', 'Malayalam', 'Old_Church_Slavonic_(Cyrillic)', 'Keble', 'Aurek-Besh', 'Atlantean', 'Kannada', 'Glagolitic', 'Angelic', 'Avesta', 'Gurmukhi', 'Ge_ez', 'Atemayar_Qelisayer']

# %%
def get_batch(batch_size,s="train"):
    """Create batch of n pairs, half same class, half different class"""
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape

    # randomly sample several classes to use in the batch
    categories = rng.choice(n_classes,size=(batch_size,),replace=False)

    # initialize 2 empty arrays for the input image batch
    pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]

    # initialize vector for the targets
    targets=np.zeros((batch_size,))

    # make one half of it '1's, so 2nd half of batch has same class
    targets[batch_size//2:] = 1
    for i in range(batch_size):
        category = categories[i]
        idx_1 = rng.randint(0, n_examples)
        pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
        idx_2 = rng.randint(0, n_examples)

        # pick images of same class for 1st half, different for 2nd
        if i >= batch_size // 2:
            category_2 = category
        else:
            # add a random number to the category modulo n classes to ensure 2nd image has a different category
            category_2 = (category + rng.randint(1,n_classes)) % n_classes

        pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)

    return pairs, targets

# %%
def generate(batch_size, s="train"):
    """a generator for batches, so model.fit_generator can be used. """
    while True:
        pairs, targets = get_batch(batch_size,s)
        yield (pairs, targets)

# %%
def make_oneshot_task(N, s="val", language=None):
    """Create pairs of test image, support set for testing N way one-shot learning. """
    if s == 'train':
        X = Xtrain
        categories = train_classes
    else:
        X = Xval
        categories = val_classes
    n_classes, n_examples, w, h = X.shape

    indices = rng.randint(0, n_examples,size=(N,))
    if language is not None: # if language is specified, select characters for that language
        low, high = categories[language]
        if N > high - low:
            raise ValueError("This language ({}) has less than {} letters".format(language, N))
        categories = rng.choice(range(low,high),size=(N,),replace=False)

    else: # if no language specified just pick a bunch of random letters
        categories = rng.choice(range(n_classes),size=(N,),replace=False)
    true_category = categories[0]
    ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
    test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
    support_set = X[categories,indices,:,:]
    support_set[0,:,:] = X[true_category,ex2]
    support_set = support_set.reshape(N, w, h,1)
    targets = np.zeros((N,))
    targets[0] = 1
    targets, test_image, support_set = shuffle(targets, test_image, support_set)
    pairs = [test_image,support_set]

    return pairs, targets

# %%
def test_oneshot(model, N, k, s = "val", verbose = 0):
    """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
    n_correct = 0
    if verbose:
        print("Evaluating model on {} random {} way one-shot learning tasks ... \n".format(k,N))
    for i in range(k):
        inputs, targets = make_oneshot_task(N,s)
        probs = model.predict(inputs)
        if np.argmax(probs) == np.argmax(targets):
            n_correct+=1
    percent_correct = (100.0 * n_correct / k)
    if verbose:
        print("Got an average of {}% {} way one-shot learning accuracy \n".format(percent_correct,N))
    return percent_correct

# %%
# Hyper parameters
evaluate_every = 200 # interval for evaluating on one-shot tasks
batch_size = 32
n_iter = 2000 # No. of training iterations
N_way = 20 # how many classes for testing one-shot tasks
n_val = 250 # how many one-shot tasks to validate on
best = -1

# %%
model_path = '/content/drive/MyDrive/Honors_project/Dataset/Save_model'
if not os.path.exists(model_path):
    os.makedirs(model_path)

# %%
print("Starting training process!")
print("-------------------------------------")
t_start = time.time()
for i in range(1, n_iter+1):
    (inputs,targets) = get_batch(batch_size)
    loss = model.train_on_batch(inputs, targets)
    if i % evaluate_every == 0:
        print("\n ------------- \n")
        print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
        print("Train Loss: {0}".format(loss))
        val_acc = test_oneshot(model, N_way, n_val, verbose=True)
        model.save_weights(os.path.join(model_path, 'weights.{}.h5'.format(i)))
        if val_acc >= best:
            print("Current best: {0}, previous best: {1}".format(val_acc, best))
            best = val_acc
# Out:
# Starting training process!
# -------------------------------------

# %%
model.load_weights('/content/drive/MyDrive/Honors_project/Dataset/Save_model/weights.2000.h5')

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0

# %%
def test_nn_accuracy(N_ways,n_trials):
    """Returns accuracy of NN approach """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))

    n_right = 0

    for i in range(n_trials):
        pairs,targets = make_oneshot_task(N_ways,"val")
        correct = nearest_neighbour_correct(pairs,targets)
        n_right += correct
    return 100.0 * n_right / n_trials

# %%
ways = np.arange(1,20,2)
resume =  False
trials = 50

# %%
val_accs, train_accs,nn_accs = [], [], []
for N in ways:
    val_accs.append(test_oneshot(model, N, trials, "val", verbose=True))
    train_accs.append(test_oneshot(model, N, trials, "train", verbose=True))
    nn_acc = test_nn_accuracy(N, trials)
    nn_accs.append(nn_acc)
    print ("NN Accuracy = ", nn_acc)
    print("---------------------------------------------------------------------------------------------------------------")
# Out:
# Evaluating model on 50 random 1 way one-shot learning tasks ...
#
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 369ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 109ms/step
# Got an average of 100.0% 1 way one-shot learning accuracy
#
# Evaluating model on 50 random 1 way one-shot learning tasks ...
#
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 110ms/step
# Got an average of 100.0% 1 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 1 way one-shot learning tasks ...
# NN Accuracy =  100.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 3 way one-shot learning tasks ...
# <ipython-input-27-0e6416d38168>:6: RuntimeWarning: invalid value encountered in sqrt
#   L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 460ms/step
# 1/1 [==============================] - 0s 428ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 449ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 273ms/step
# Got an average of 48.0% 3 way one-shot learning accuracy
#
# Evaluating model on 50 random 3 way one-shot learning tasks ...
#
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 273ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 371ms/step
# 1/1 [==============================] - 0s 405ms/step
# 1/1 [==============================] - 0s 435ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 407ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 269ms/step
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 276ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 346ms/step
# 1/1 [==============================] - 0s 278ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 311ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 409ms/step
# 1/1 [==============================] - 0s 451ms/step
# 1/1 [==============================] - 0s 387ms/step
# Got an average of 54.0% 3 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 3 way one-shot learning tasks ...
# NN Accuracy =  30.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 5 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 625ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 635ms/step
# 1/1 [==============================] - 0s 495ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 394ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 0s 412ms/step
# 1/1 [==============================] - 0s 452ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 0s 430ms/step
# 1/1 [==============================] - 0s 400ms/step
# 1/1 [==============================] - 0s 419ms/step
# 1/1 [==============================] - 0s 384ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 393ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 417ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 424ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 1s 537ms/step
# Got an average of 42.0% 5 way one-shot learning accuracy
#
# Evaluating model on 50 random 5 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 683ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 649ms/step
# 1/1 [==============================] - 1s 672ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 0s 418ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 389ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 0s 410ms/step
# 1/1 [==============================] - 0s 381ms/step
# 1/1 [==============================] - 1s 545ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 652ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 649ms/step
# 1/1 [==============================] - 1s 659ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 0s 398ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 383ms/step
# 1/1 [==============================] - 0s 387ms/step
# 1/1 [==============================] - 0s 388ms/step
# 1/1 [==============================] - 0s 386ms/step
# 1/1 [==============================] - 0s 395ms/step
# 1/1 [==============================] - 0s 368ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 390ms/step
# 1/1 [==============================] - 0s 377ms/step
# 1/1 [==============================] - 0s 385ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 375ms/step
# 1/1 [==============================] - 0s 371ms/step
# Got an average of 40.0% 5 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 5 way one-shot learning tasks ...
# NN Accuracy =  10.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 7 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 529ms/step
# 1/1 [==============================] - 1s 647ms/step
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 1s 510ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 1s 520ms/step
# 1/1 [==============================] - 1s 502ms/step
# 1/1 [==============================] - 1s 510ms/step
# 1/1 [==============================] - 1s 524ms/step
# 1/1 [==============================] - 0s 494ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 1s 511ms/step
# 1/1 [==============================] - 1s 513ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 1s 505ms/step
# 1/1 [==============================] - 1s 677ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 868ms/step
# 1/1 [==============================] - 1s 819ms/step
# 1/1 [==============================] - 1s 802ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 510ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 1s 512ms/step
# 1/1 [==============================] - 0s 490ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 1s 512ms/step
# 1/1 [==============================] - 1s 517ms/step
# 1/1 [==============================] - 0s 491ms/step
# 1/1 [==============================] - 1s 515ms/step
# 1/1 [==============================] - 1s 538ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 1s 533ms/step
# 1/1 [==============================] - 1s 819ms/step
# 1/1 [==============================] - 1s 861ms/step
# 1/1 [==============================] - 1s 787ms/step
# Got an average of 46.0% 7 way one-shot learning accuracy
#
# Evaluating model on 50 random 7 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 1s 790ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 958ms/step
# 1/1 [==============================] - 1s 845ms/step
# 1/1 [==============================] - 1s 797ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 797ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 774ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 0s 492ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 1s 511ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 0s 498ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 0s 496ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 0s 499ms/step
# 1/1 [==============================] - 1s 528ms/step
# 1/1 [==============================] - 1s 500ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 773ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 794ms/step
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 1s 525ms/step
# 1/1 [==============================] - 0s 497ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 0s 495ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 509ms/step
# 1/1 [==============================] - 1s 508ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 1s 514ms/step
# 1/1 [==============================] - 1s 511ms/step
# 1/1 [==============================] - 1s 507ms/step
# 1/1 [==============================] - 1s 518ms/step
# 1/1 [==============================] - 1s 503ms/step
# 1/1 [==============================] - 1s 510ms/step
# Got an average of 30.0% 7 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 7 way one-shot learning tasks ...
# NN Accuracy =  18.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 9 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 773ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 642ms/step
# 1/1 [==============================] - 1s 659ms/step
# 1/1 [==============================] - 1s 619ms/step
# 1/1 [==============================] - 1s 653ms/step
# 1/1 [==============================] - 1s 633ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 643ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 637ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 634ms/step
# 1/1 [==============================] - 1s 937ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 630ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 634ms/step
# 1/1 [==============================] - 1s 649ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 624ms/step
# 1/1 [==============================] - 1s 665ms/step
# 1/1 [==============================] - 1s 657ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 625ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 897ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 935ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 633ms/step
# 1/1 [==============================] - 1s 619ms/step
# 1/1 [==============================] - 1s 614ms/step
# Got an average of 28.0% 9 way one-shot learning accuracy
#
# Evaluating model on 50 random 9 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 630ms/step
# 1/1 [==============================] - 1s 623ms/step
# 1/1 [==============================] - 1s 865ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 938ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 627ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 642ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 635ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 651ms/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 635ms/step
# 1/1 [==============================] - 1s 809ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 999ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 647ms/step
# 1/1 [==============================] - 1s 624ms/step
# 1/1 [==============================] - 1s 625ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 632ms/step
# Got an average of 40.0% 9 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 9 way one-shot learning tasks ...
# NN Accuracy =  12.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 11 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 783ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 738ms/step
# 1/1 [==============================] - 1s 760ms/step
# 1/1 [==============================] - 1s 749ms/step
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 1s 734ms/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 745ms/step
# 1/1 [==============================] - 1s 736ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 1s 766ms/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 985ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 762ms/step
# 1/1 [==============================] - 1s 760ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 44.0% 11 way one-shot learning accuracy
#
# Evaluating model on 50 random 11 way one-shot learning tasks ...
#
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 727ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 745ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 733ms/step
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 1s 746ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 1s 743ms/step
# 1/1 [==============================] - 1s 745ms/step
# 1/1 [==============================] - 1s 761ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 1s 734ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 800ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 749ms/step
# 1/1 [==============================] - 1s 746ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 1s 739ms/step
# Got an average of 28.0% 11 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 11 way one-shot learning tasks ...
# NN Accuracy =  8.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 13 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 858ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 890ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 877ms/step
# 1/1 [==============================] - 1s 880ms/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 876ms/step
# 1/1 [==============================] - 1s 885ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 877ms/step
# 1/1 [==============================] - 1s 870ms/step
# 1/1 [==============================] - 1s 881ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 30.0% 13 way one-shot learning accuracy
#
# Evaluating model on 50 random 13 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 867ms/step
# 1/1 [==============================] - 1s 855ms/step
# 1/1 [==============================] - 1s 884ms/step
# 1/1 [==============================] - 1s 883ms/step
# 1/1 [==============================] - 1s 877ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 885ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 890ms/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 898ms/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 884ms/step
# 1/1 [==============================] - 1s 886ms/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 878ms/step
# 1/1 [==============================] - 1s 896ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 875ms/step
# 1/1 [==============================] - 1s 879ms/step
# 1/1 [==============================] - 1s 886ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 872ms/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 857ms/step
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 1s 869ms/step
# 1/1 [==============================] - 1s 924ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 873ms/step
# 1/1 [==============================] - 1s 882ms/step
# 1/1 [==============================] - 1s 875ms/step
# Got an average of 22.0% 13 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 13 way one-shot learning tasks ...
# NN Accuracy =  4.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 15 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 34.0% 15 way one-shot learning accuracy
#
# Evaluating model on 50 random 15 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 30.0% 15 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 15 way one-shot learning tasks ...
# NN Accuracy =  4.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 17 way one-shot learning tasks ...
#
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 38.0% 17 way one-shot learning accuracy
#
# Evaluating model on 50 random 17 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 14.0% 17 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 17 way one-shot learning tasks ...
# NN Accuracy =  10.0
# ---------------------------------------------------------------------------------------------------------------
# Evaluating model on 50 random 19 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 26.0% 19 way one-shot learning accuracy
#
# Evaluating model on 50 random 19 way one-shot learning tasks ...
#
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Got an average of 36.0% 19 way one-shot learning accuracy
#
# Evaluating nearest neighbour on 50 unique 19 way one-shot learning tasks ...
# NN Accuracy =  8.0
# ---------------------------------------------------------------------------------------------------------------

# %%
#with open(os.path.join(save_path,"accuracies.pickle"), "wb") as f:
#    pickle.dump((val_accs,train_accs,nn_accs),f)
f = open(save_path+"accuracies.pickle","wb")
pickle.dump((val_accs,train_accs,nn_accs),f)
f.close()

# %%
#with open(os.path.join(save_path, "accuracies.pickle"), "rb") as f:
#    (val_accs, train_accs, nn_accs) = pickle.load(f)
f = open(save_path+"/accuracies.pickle","rb")
(val_accs, train_accs, nn_accs) = pickle.load(f)
f.close()

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc, h , w, _ = X.shape
    X = X.reshape(nc, h, w)
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img

# %%
def plot_oneshot_task(pairs):
    fig,(ax1,ax2) = plt.subplots(nrows=1, ncols=2)
    ax1.matshow(pairs[0][0].reshape(105,105), cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
# Example of concat image visualization
pairs, targets = make_oneshot_task(16,"train","Sanskrit")
plot_oneshot_task(pairs)

# %%
fig,ax = plt.subplots(1)
ax.plot(ways, val_accs, "m", label="Siamese(val set)")
ax.plot(ways, train_accs, "y", label="Siamese(train set)")
plt.plot(ways, nn_accs, label="Nearest neighbour")

ax.plot(ways, 100.0/ways, "g", label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Omiglot One-Shot Learning Performance of a Siamese Network")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs,targets = make_oneshot_task(20, "val", 'Oriya')
plt.show()

plot_oneshot_task(inputs)

# %%
plt.savefig('plot.png')
